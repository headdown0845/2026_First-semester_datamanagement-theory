# %% [markdown]
# <a href="https://colab.research.google.com/github/headdown0845/2026_First-semester_datamanagement-theory/blob/main/260508_2355022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
x = torch.tensor(1.0, requires_grad=True)

# %%
y = x + 2

# %%
y = x**2+ 2

# %%
y.grad_fn

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(2.)

# %%
# import torch

# Our batch of data will have 10 data points
N = 10
# Each data point has 1 input feature and 1 output value
D_in = 1
D_out = 1
# Create our input data X
X = torch.randn(N, D_in)

# Create our true target labels y by using the "true" W and b
# The "true" W is 2.0, the "true" b is 1.0
true_W = torch.tensor([[2.0]])
true_b = torch.tensor(1.0)
y_true = X @ true_W + true_b + torch.randn(N, D_out) * 0.1 # Add a little noise

# Hyperparameters
learning_rate, epochs = 0.01, 300

# %%
W = torch.randn(1, 1, requires_grad=True)
b = torch.randn(1, requires_grad=True)

# %%
for epoch in range(epochs):
    # Forward pass and loss
    y_hat = X @ W + b
    loss = torch.mean((y_hat - y_true)**2)

# %%
y_hat
# Out:
# tensor([[-0.5089],
#         [-1.5425],
#         [-0.5580],
#         [-0.9133],
#         [-1.0197],
#         [-0.9861],
#         [-0.7530],
#         [-0.8964],
#         [-0.6782],
#         [-0.6366]], grad_fn=<AddBackward0>)

# %%
# Backward pass
loss.backward()

# %%
# Update parameters
with torch.no_grad():
        W -= learning_rate * W.grad
        b -= learning_rate * b.grad

# %%
# Zero gradients
W.grad.zero_(); b.grad.zero_()
# Out:
# tensor([0.])

# %%
if epoch % 30 == 0:
    print(f"Epoch {epoch:02d}: Loss={loss.item():.4f}, W={W.item():.3f}, b={b.item():.3f}")

print(f"\nFinal Parameters: W={W.item():.3f}, b={b.item():.3f}")
print(f"True Parameters:  W=2.000, b=1.000")
# Out:
# Final Parameters: W=-0.281, b=-0.784
# True Parameters:  W=2.000, b=1.000

# %%
N = 10

# %%
D_in =1
D_out = 1

# %%
X = torch.randn(N, D_in)

# %%
true_W = torch.tensor([[2.0]])
true_b = torch.tensor(1.0)
y_true = X @ true_W + true_b + torch.randn(N, D_out) * 0.1

# %%
error = y_hat - y_true

# %%
squared_error = error ** 2

# %%
loss = squared_error.mean()

# %%
print(f"Loss (our single scorecard number):{loss}")
# Out:
# Loss (our single scorecard number):6.986897945404053

# %%
torch.no_grad()

# %%
import torch.optim as optim

learning_rate, epochs = 0.01, 100
W, b = torch.randn(1, 1, requires_grad=True), torch.randn(1, requires_grad=True)

optimizer = torch.optim.SGD([W, b], lr=learning_rate)

# %%
for epoch in range(epochs):
    y_hat = X @ W + b
    loss = torch.mean((y_hat - y_true)**2)

# %%
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
class LinearRegressionModel(nn.Module):
  def __init__(self):
     super(LinearRegressionModel, self).__init__()
     # W, b를 자동 생성 Linear 레이어(입력1, 출력1)
     self.linear = nn.Linear(1, 1)

# %%
def forward(self, x):
     # 1단계: 예측 (y_hat = X @     W + b)
     return self.linear(x)

# %%
learning_rate = 0.01; epochs = 100

# %%
model = LinearRegressionModel()

# %%
criterion = nn.MSELoss() #손실함수

# %%
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

# %%
for epoch in range(epochs):
    optimizer.zero_grad() 	# 기울기 초기화
    y_hat = model(X)      	# 모델을 통한 예측
    loss = criterion(y_hat, y_true) 	# 손실 계산
    loss.backward()        	# 역전파(기울기 계산)
    optimizer.step()       	# 파라미터 업데이트

    if (epoch + 1) % 10 == 0:
         print(f'Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipykernel_923/534422480.py in <cell line: 0>()
#       1 for epoch in range(epochs):
#       2     optimizer.zero_grad()       # 기울기 초기화
# ----> 3     y_hat = model(X)            # 모델을 통한 예측
#       4     loss = criterion(y_hat, y_true)     # 손실 계산
#       5     loss.backward()             # 역전파(기울기 계산)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _forward_unimplemented(self, *input)
#     401         registered hooks while the latter silently ignores them.
#     402     """
# --> 403     raise NotImplementedError(
#     404         f'Module [{type(self).__name__}] is missing the required "forward" function'
#     405     )
#
# NotImplementedError: Module [LinearRegressionModel] is missing the required "forward" function

# %%
for epoch in range(epochs):
    for batch_X, batch_y in dataloader:
        # 1. 기울기 계산
        gradient = compute_gradient(batch_X, batch_y)

        # 2. 엔진 1: 관성(Momentum) 계산 (방향 결정)
        # beta 1 = 엑세레이터, beta 2 = 브레이크
        m = beta1 * m + (1 - beta1) * gradient

        # 3. 엔진 2: 보폭(RMSProp) 조절 (보폭 결정)
        v = beta2 * v + (1 - beta2) * (gradient**2)

        # 4. 파라미터 업데이트
        # 방향(m)을 보폭조절장치(root v)로 효율적으로 이동
        W -= learning_rate * m / (sqrt(v) + epsilon)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_923/2776465438.py in <cell line: 0>()
#       1 for epoch in range(epochs):
# ----> 2     for batch_X, batch_y in dataloader:
#       3         # 1. 기울기 계산
#       4         gradient = compute_gradient(batch_X, batch_y)
#       5
#
# NameError: name 'dataloader' is not defined

# %%
import torch.nn as nn
import torch.optim as optim

class AntiOverfitModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer = nn.Sequential(
            nn.Linear(100, 64),
            nn.BatchNorm1d(64), # 배치 정규화
            nn.ReLU(),
            nn.Dropout(0.3),    # 드롭아웃 (30% 확률)
            nn.Linear(64, 10)
        )

# 가중치 감쇠(L2 Regularization)는 Optimizer에서 설정
optimizer = optim.Adam(model.parameters(), lr=0.01, weight_decay=1e-4)
